# %% [markdown]
# <a href="https://colab.research.google.com/github/geek316/DSA/blob/master/arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Linear Search
"""
print("Linear Search")

new_list = [1,2,3]
print("List:",new_list)

print("\nCheck if 1 is in the list:")
if 1 in new_list: print(True)

for n in new_list:
  if n ==1:
    print(True)
    break
else:
  print(n, " is not in list")

for n in new_list:
  if n ==10:
    print(True)
    break
else:
  print(n, " is not in list")


"""
Insert
"""
print("\nInsert in list")

new_list = []
print("List:", new_list)

new_list.append(2)
print("List after appending 2:", new_list)

new_list.append(200)
print("List after appending 200:", new_list)
print("Length of the list:", len(new_list))


new_list.insert(10,0)
print("\nInserting 10 at 0th position in the list:", new_list)

new_list.extend([1,2,3])
print("Extending list with list[1,2,3] : ",new_list)


"""
Delete
"""
print("\nDelete in list")

del(new_list[0])
print("Deleting element from 0th position in the list:", new_list)

del(new_list)
print("Deleting entire list")
# Out:
# Linear Search
# List: [1, 2, 3]
#
# Check if 1 is in the list:
# True
# True
# 3  is not in list
#
# Insert in list
# List: []
# List after appending 2: [2]
# List after appending 200: [2, 200]
# Length of the list: 2
#
# Inserting 10 at 0th position in the list: [2, 200, 0]
# Extending list with list[1,2,3] :  [2, 200, 0, 1, 2, 3]
#
# Delete in list
# Deleting element from 0th position in the list: [200, 0, 1, 2, 3]
# Deleting entire list
